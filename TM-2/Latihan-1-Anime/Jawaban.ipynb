# %%
# Import libraries
import numpy as np
import tensorflow as tf
import tensorflow.keras as keras
import matplotlib.pyplot as plt
import os

# %%
# !unzip /content/Dataset.zip -d /content/extracted

# %%
# Load images
image_path = "./data/"

images = []

for filename in os.listdir(image_path):
    img = tf.keras.preprocessing.image.load_img(f"{image_path}{filename}", target_size=(64, 64))
    img = tf.keras.preprocessing.image.img_to_array(img)
    images.append(img)

# %%
# Preprocess Images
images = np.asarray(images)

# Shuffle
indices = np.arange(images.shape[0])
np.random.shuffle(indices)
images = images[indices]

# Normalize
images = images.astype(np.float32) / 255.0

# Split dataset
total_data = len(images)
train_count = int(0.8 * total_data) # 80%

x_train = images[:train_count] # ambil 80% pertama
x_test = images[train_count : ] # ambil sisanya

print(f"Total Data: {total_data}")
print(f"Train: {x_train.shape}, Test: {x_test.shape}")
# Out:
# Total Data: 21551
# Train: (17240, 64, 64, 3), Test: (4311, 64, 64, 3)

# %%
BATCH_SIZE = 100
IMAGE_ORIGINAL_SHAPE = x_train.shape[1:]
IMAGE_SIZE = IMAGE_ORIGINAL_SHAPE[0] * IMAGE_ORIGINAL_SHAPE[1] * IMAGE_ORIGINAL_SHAPE[2]
HIDDEN_DIM = 512 
LATENT_DIM = 32 
MAX_EPOCHS = 60
LEARNING_RATE = 0.0001

print(IMAGE_ORIGINAL_SHAPE, IMAGE_SIZE)
# Out:
# (64, 64, 3) 12288

# %%
# Define model
class VAE(tf.keras.Model):
    def __init__(self, dim, **kwargs):
        super(VAE, self).__init__(**kwargs)

        h_dim = dim[0]
        z_dim = dim[1]

        self.fc1 = tf.keras.layers.Dense(h_dim, activation=tf.nn.relu)
        self.fc2 = tf.keras.layers.Dense(z_dim) 
        self.fc3 = tf.keras.layers.Dense(z_dim)
        self.fc4 = tf.keras.layers.Dense(h_dim, activation=tf.nn.relu)
        self.fc5 = tf.keras.layers.Dense(IMAGE_SIZE)

        self.encoder_batch_norm = tf.keras.layers.BatchNormalization()
        self.decoder_batch_norm = tf.keras.layers.BatchNormalization()

    def encode(self, x):
        x = self.encoder_batch_norm(x) 
        h = self.fc1(x) 
        return self.fc2(h), self.fc3(h) 

    def reparameterize(self, mu, log_var):
        std = tf.exp(log_var * 0.5)
        eps = tf.random.normal(tf.shape(std))
        return mu + eps * std 

    def decode_logits(self, z):
        h = self.fc4(z) 
        h = self.fc5(h) 
        return self.decoder_batch_norm(h) 

    def decode(self, z):
        return tf.nn.sigmoid(self.decode_logits(z))

    def call(self, inputs, training=None, mask=None):
        mu, log_var = self.encode(inputs) 
        z = self.reparameterize(mu, log_var) 
        x_recon_logits = self.decode_logits(z) 
        return x_recon_logits, mu, log_var

# %%
# Model initialization
model = VAE([HIDDEN_DIM, LATENT_DIM])

dummy = tf.zeros((BATCH_SIZE, IMAGE_SIZE))

model(dummy)

model.summary()

optimizer = tf.keras.optimizers.Adam(LEARNING_RATE)

dataset = tf.data.Dataset.from_tensor_slices(x_train) 
dataset = dataset.shuffle(BATCH_SIZE * 5).batch(BATCH_SIZE)
# Out:
# Model: "vae"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               multiple                  6291968
#
#  dense_1 (Dense)             multiple                  16416
#
#  dense_2 (Dense)             multiple                  16416
#
#  dense_3 (Dense)             multiple                  16896
#
#  dense_4 (Dense)             multiple                  6303744
#
#  batch_normalization (BatchN  multiple                 49152
#  ormalization)
#
#  batch_normalization_1 (Batc  multiple                 49152
#  hNormalization)
#
# =================================================================
# Total params: 12,743,744
# Trainable params: 12,694,592
# Non-trainable params: 49,152
# _________________________________________________________________

# %%
# Train model
loss_history = []
kl_div_history = []

for epoch in range(MAX_EPOCHS):
    for x in dataset:
        x = tf.reshape(x, [-1, IMAGE_SIZE])
        with tf.GradientTape() as tape:
            x_reconstruction_logits, mu, log_var = model(x)

            reconstruction_loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=x, logits=x_reconstruction_logits)
            reconstruction_loss = tf.reduce_sum(reconstruction_loss) / BATCH_SIZE

            kl_div = -0.5 * tf.reduce_sum(1. + log_var - tf.square(mu) - tf.exp(log_var), axis = -1)
            kl_div = tf.reduce_mean(kl_div)

            loss = tf.reduce_mean(reconstruction_loss + kl_div)
        gradients = tape.gradient(loss, model.trainable_variables)
        gradients = [tf.clip_by_norm(g, 15) for g in gradients]

        optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    print(f"Epoch[{epoch+1}/{MAX_EPOCHS}] Reconstruction Loss: {float(reconstruction_loss):.2f}, KL DIV: {float(kl_div):.2f}, Loss : {float(loss):.2f}")
    kl_div_history.append(kl_div)
    loss_history.append(loss)
# Out:
# Epoch[1/60] Reconstruction Loss: 2853.45, KL DIV: 56.31, Loss : 2909.76
# Epoch[2/60] Reconstruction Loss: 2723.62, KL DIV: 53.98, Loss : 2777.60
# Epoch[3/60] Reconstruction Loss: 2676.04, KL DIV: 56.30, Loss : 2732.34
# Epoch[4/60] Reconstruction Loss: 2600.10, KL DIV: 60.84, Loss : 2660.94
# Epoch[5/60] Reconstruction Loss: 2603.27, KL DIV: 63.99, Loss : 2667.26
# Epoch[6/60] Reconstruction Loss: 2636.22, KL DIV: 57.99, Loss : 2694.21
# Epoch[7/60] Reconstruction Loss: 2656.29, KL DIV: 60.63, Loss : 2716.92
# Epoch[8/60] Reconstruction Loss: 2695.28, KL DIV: 60.56, Loss : 2755.84
# Epoch[9/60] Reconstruction Loss: 2657.80, KL DIV: 61.94, Loss : 2719.75
# Epoch[10/60] Reconstruction Loss: 2589.83, KL DIV: 60.52, Loss : 2650.35
# Epoch[11/60] Reconstruction Loss: 2531.37, KL DIV: 64.39, Loss : 2595.75
# Epoch[12/60] Reconstruction Loss: 2535.98, KL DIV: 65.48, Loss : 2601.46
# Epoch[13/60] Reconstruction Loss: 2556.58, KL DIV: 65.48, Loss : 2622.06
# Epoch[14/60] Reconstruction Loss: 2656.43, KL DIV: 63.25, Loss : 2719.68
# Epoch[15/60] Reconstruction Loss: 2587.19, KL DIV: 64.43, Loss : 2651.62
# Epoch[16/60] Reconstruction Loss: 2685.17, KL DIV: 61.76, Loss : 2746.93
# Epoch[17/60] Reconstruction Loss: 2617.16, KL DIV: 64.88, Loss : 2682.03
# Epoch[18/60] Reconstruction Loss: 2603.39, KL DIV: 67.56, Loss : 2670.95
# Epoch[19/60] Reconstruction Loss: 2581.22, KL DIV: 66.34, Loss : 2647.56
# Epoch[20/60] Reconstruction Loss: 2621.61, KL DIV: 66.25, Loss : 2687.86
# Epoch[21/60] Reconstruction Loss: 2570.32, KL DIV: 64.95, Loss : 2635.27
# Epoch[22/60] Reconstruction Loss: 2653.91, KL DIV: 64.04, Loss : 2717.95
# Epoch[23/60] Reconstruction Loss: 2617.29, KL DIV: 65.56, Loss : 2682.85
# Epoch[24/60] Reconstruction Loss: 2563.27, KL DIV: 65.76, Loss : 2629.04
# Epoch[25/60] Reconstruction Loss: 2608.11, KL DIV: 65.56, Loss : 2673.67
# Epoch[26/60] Reconstruction Loss: 2579.86, KL DIV: 67.68, Loss : 2647.54
# Epoch[27/60] Reconstruction Loss: 2643.12, KL DIV: 65.12, Loss : 2708.24
# Epoch[28/60] Reconstruction Loss: 2606.42, KL DIV: 66.60, Loss : 2673.02
# Epoch[29/60] Reconstruction Loss: 2541.29, KL DIV: 65.77, Loss : 2607.06
# Epoch[30/60] Reconstruction Loss: 2556.84, KL DIV: 68.15, Loss : 2624.98
# Epoch[31/60] Reconstruction Loss: 2583.09, KL DIV: 65.18, Loss : 2648.27
# Epoch[32/60] Reconstruction Loss: 2602.17, KL DIV: 65.94, Loss : 2668.11
# Epoch[33/60] Reconstruction Loss: 2592.17, KL DIV: 66.41, Loss : 2658.58
# Epoch[34/60] Reconstruction Loss: 2607.39, KL DIV: 66.53, Loss : 2673.92
# Epoch[35/60] Reconstruction Loss: 2516.28, KL DIV: 69.07, Loss : 2585.36
# Epoch[36/60] Reconstruction Loss: 2604.54, KL DIV: 68.93, Loss : 2673.48
# Epoch[37/60] Reconstruction Loss: 2556.68, KL DIV: 68.21, Loss : 2624.89
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 9
#       7 x = tf.reshape(x, [-1, IMAGE_SIZE])
#       8 with tf.GradientTape() as tape:
# ----> 9     x_reconstruction_logits, mu, log_var = model(x)
#      11     reconstruction_loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=x, logits=x_reconstruction_logits)
#      12     reconstruction_loss = tf.reduce_sum(reconstruction_loss) / BATCH_SIZE
#
# File c:\Users\ASUS\xStyNWx\Documents\BINUS University\Academic Courses\Semester 5\Deep Learning\Lab\Repo\deeplearning-env\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\ASUS\xStyNWx\Documents\BINUS University\Academic Courses\Semester 5\Deep Learning\Lab\Repo\deeplearning-env\lib\site-packages\keras\engine\training.py:557, in Model.__call__(self, *args, **kwargs)
#     553         super().__call__(inputs, *copied_args, **copied_kwargs)
#     555     layout_map_lib._map_subclass_model_variable(self, self._layout_map)
# --> 557 return super().__call__(*args, **kwargs)
#
# File c:\Users\ASUS\xStyNWx\Documents\BINUS University\Academic Courses\Semester 5\Deep Learning\Lab\Repo\deeplearning-env\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\ASUS\xStyNWx\Documents\BINUS University\Academic Courses\Semester 5\Deep Learning\Lab\Repo\deeplearning-env\lib\site-packages\keras\engine\base_layer.py:1097, in Layer.__call__(self, *args, **kwargs)
#    1092     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1094 with autocast_variable.enable_auto_cast_variables(
#    1095     self._compute_dtype_object
#    1096 ):
# -> 1097     outputs = call_fn(inputs, *args, **kwargs)
#    1099 if self._activity_regularizer:
#    1100     self._handle_activity_regularization(inputs, outputs)
#
# File c:\Users\ASUS\xStyNWx\Documents\BINUS University\Academic Courses\Semester 5\Deep Learning\Lab\Repo\deeplearning-env\lib\site-packages\keras\utils\traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# Cell In[6], line 37, in VAE.call(self, inputs, training, mask)
#      36 def call(self, inputs, training=None, mask=None):
# ---> 37     mu, log_var = self.encode(inputs)
#      38     z = self.reparameterize(mu, log_var)
#      39     x_recon_logits = self.decode_logits(z)
#
# Cell In[6], line 19, in VAE.encode(self, x)
#      18 def encode(self, x):
# ---> 19     x = self.encoder_batch_norm(x)
#      20     h = self.fc1(x)
#      21     return self.fc2(h), self.fc3(h)
#
# File c:\Users\ASUS\xStyNWx\Documents\BINUS University\Academic Courses\Semester 5\Deep Learning\Lab\Repo\deeplearning-env\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\ASUS\xStyNWx\Documents\BINUS University\Academic Courses\Semester 5\Deep Learning\Lab\Repo\deeplearning-env\lib\site-packages\keras\engine\base_layer.py:1097, in Layer.__call__(self, *args, **kwargs)
#    1092     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1094 with autocast_variable.enable_auto_cast_variables(
#    1095     self._compute_dtype_object
#    1096 ):
# -> 1097     outputs = call_fn(inputs, *args, **kwargs)
#    1099 if self._activity_regularizer:
#    1100     self._handle_activity_regularization(inputs, outputs)
#
# File c:\Users\ASUS\xStyNWx\Documents\BINUS University\Academic Courses\Semester 5\Deep Learning\Lab\Repo\deeplearning-env\lib\site-packages\keras\utils\traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File c:\Users\ASUS\xStyNWx\Documents\BINUS University\Academic Courses\Semester 5\Deep Learning\Lab\Repo\deeplearning-env\lib\site-packages\keras\layers\normalization\batch_normalization.py:1029, in BatchNormalizationBase.call(self, inputs, training)
#    1027 if scale is not None:
#    1028     scale = tf.cast(scale, inputs.dtype)
# -> 1029 outputs = tf.nn.batch_normalization(
#    1030     inputs,
#    1031     _broadcast(mean),
#    1032     _broadcast(variance),
#    1033     offset,
#    1034     scale,
#    1035     self.epsilon,
#    1036 )
#    1037 if inputs_dtype in (tf.float16, tf.bfloat16):
#    1038     outputs = tf.cast(outputs, inputs_dtype)
#
# File c:\Users\ASUS\xStyNWx\Documents\BINUS University\Academic Courses\Semester 5\Deep Learning\Lab\Repo\deeplearning-env\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\ASUS\xStyNWx\Documents\BINUS University\Academic Courses\Semester 5\Deep Learning\Lab\Repo\deeplearning-env\lib\site-packages\tensorflow\python\util\dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\ASUS\xStyNWx\Documents\BINUS University\Academic Courses\Semester 5\Deep Learning\Lab\Repo\deeplearning-env\lib\site-packages\tensorflow\python\ops\nn_impl.py:1588, in batch_normalization(x, mean, variance, offset, scale, variance_epsilon, name)
#    1535 r"""Batch normalization.
#    1536
#    1537 Normalizes a tensor by `mean` and `variance`, and applies (optionally) a
#    (...)
#    1585     ([pdf](http://proceedings.mlr.press/v37/ioffe15.pdf))
#    1586 """
#    1587 with ops.name_scope(name, "batchnorm", [x, mean, variance, scale, offset]):
# -> 1588   inv = math_ops.rsqrt(variance + variance_epsilon)
#    1589   if scale is not None:
#    1590     inv *= scale
#
# File c:\Users\ASUS\xStyNWx\Documents\BINUS University\Academic Courses\Semester 5\Deep Learning\Lab\Repo\deeplearning-env\lib\site-packages\tensorflow\python\ops\variables.py:1074, in Variable._OverloadOperator.<locals>._run_op(a, *args, **kwargs)
#    1072 def _run_op(a, *args, **kwargs):
#    1073   # pylint: disable=protected-access
# -> 1074   return tensor_oper(a.value(), *args, **kwargs)
#
# File c:\Users\ASUS\xStyNWx\Documents\BINUS University\Academic Courses\Semester 5\Deep Learning\Lab\Repo\deeplearning-env\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:582, in BaseResourceVariable.value(self)
#     580   return self._cached_value
#     581 with ops.colocate_with(None, ignore_existing=True):
# --> 582   return self._read_variable_op()
#
# File c:\Users\ASUS\xStyNWx\Documents\BINUS University\Academic Courses\Semester 5\Deep Learning\Lab\Repo\deeplearning-env\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:704, in BaseResourceVariable._read_variable_op(self, no_copy)
#     702       result = read_and_set_handle(no_copy)
#     703 else:
# --> 704   result = read_and_set_handle(no_copy)
#     706 if not context.executing_eagerly():
#     707   # Note that if a control flow context is active the input of the read op
#     708   # might not actually be the handle. This line bypasses it.
#     709   tape.record_operation(
#     710       "ReadVariableOp", [result], [self.handle],
#     711       backward_function=lambda x: [x],
#     712       forward_function=lambda x: [x])
#
# File c:\Users\ASUS\xStyNWx\Documents\BINUS University\Academic Courses\Semester 5\Deep Learning\Lab\Repo\deeplearning-env\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:694, in BaseResourceVariable._read_variable_op.<locals>.read_and_set_handle(no_copy)
#     692 if no_copy and forward_compat.forward_compatible(2022, 5, 3):
#     693   gen_resource_variable_ops.disable_copy_on_read(self.handle)
# --> 694 result = gen_resource_variable_ops.read_variable_op(
#     695     self.handle, self._dtype)
#     696 _maybe_set_handle_data(self._dtype, self.handle, result)
#     697 return result
#
# File c:\Users\ASUS\xStyNWx\Documents\BINUS University\Academic Courses\Semester 5\Deep Learning\Lab\Repo\deeplearning-env\lib\site-packages\tensorflow\python\ops\gen_resource_variable_ops.py:524, in read_variable_op(resource, dtype, name)
#     522 if tld.is_eager:
#     523   try:
# --> 524     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     525       _ctx, "ReadVariableOp", name, resource, "dtype", dtype)
#     526     return _result
#     527   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# Plotting
plt.figure(figsize=(20,4))
plt.subplot(1,2,1)
plt.plot(loss_history)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Loss History")

plt.subplot(1,2,2)
plt.plot(kl_div_history)
plt.xlabel("Epoch")
plt.ylabel("KL Div")
plt.title("KL Div History")

plt.show()

# %%
# Implement model for reconstruction test data
mu, log_var = model.encode(x_test.reshape(-1, IMAGE_SIZE))
z = model.reparameterize(mu, log_var)

out = model.decode(z)
out = tf.reshape(out, [-1, IMAGE_ORIGINAL_SHAPE[0], IMAGE_ORIGINAL_SHAPE[1], IMAGE_ORIGINAL_SHAPE[2]]).numpy() * 255
out = out.astype(np.uint8)

number = 10
plt.figure(figsize=(20, 8))

for index in range(number):
    ax = plt.subplot(2, number, index+1)
    plt.imshow(x_test[index].reshape(64, 64, 3))
    ax.axis('off')

for index in range(number):
    ax = plt.subplot(2, number, number + index + 1)
    plt.imshow(out[index])
    ax.axis('off')

plt.tight_layout()
plt.show()
