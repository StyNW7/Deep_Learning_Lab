# %% [markdown]
# # Import Library

# %%
import os
import tensorflow as tf
import tensorflow.keras as keras
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Dataset

# %%
data_path = "../Latihan-2-Bear/Dataset/"

images = []

for filename in os.listdir(data_path):
    image = tf.keras.preprocessing.image.load_img(f"{data_path}{filename}", target_size=(64, 64))
    image = tf.keras.preprocessing.image.img_to_array(image)
    images.append(image)

# %% [markdown]
# # Preprocessing

# %%
images = np.asarray(images)

indices = np.arange(images.shape[0])
np.random.shuffle(indices)
images = images[indices]

images = images.astype(np.float32) / 255.0

total_data = len(images)
train_count = int(total_data * 0.8)

x_train = images[:train_count]
x_test = images[train_count:]

print (f"Total Data: {total_data}")
print (f"Train : {x_train.shape}, Test : {x_test.shape}")
# Out:
# Total Data: 300
# Train : (240, 64, 64, 3), Test : (60, 64, 64, 3)
